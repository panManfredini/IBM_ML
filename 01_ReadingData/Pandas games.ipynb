# %%
import numpy as np
import pandas as pd

# %%
dates = pd.date_range("20210107", periods=9)

# %%
dates
# Out:
# DatetimeIndex(['2021-01-07', '2021-01-08', '2021-01-09', '2021-01-10',
#                '2021-01-11', '2021-01-12', '2021-01-13', '2021-01-14',
#                '2021-01-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(1000,3), columns=["A","B","C"])

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
g = pd.DataFrame(np.random.random((3,3)),index=["A","B","C"], columns=["ul","kil","pul"])

# %%
g.loc["A"]
# Out:
# ul     0.423059
# kil    0.969058
# pul    0.018603
# Name: A, dtype: float64

# %%
g.loc["D"] = g.loc["A"] - g.loc["B"]

# %%
g
# Out:
#          ul       kil       pul
# A  0.423059  0.969058  0.018603
# B  0.112243  0.601542  0.091861
# C  0.709370  0.786245  0.715780
# D  0.310816  0.367516 -0.073258
